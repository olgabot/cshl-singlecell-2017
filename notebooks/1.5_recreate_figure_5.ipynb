# %% [markdown]
# # Recreate Figure 5
#
# The purpose of this notebook is to combine all the digital gene expression data for the retina cells, downloaded from the Gene Expression Omnibus using the accession number [GSE63473](https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE63473).

# %%
import os
import common

# Assign notebook and folder names
notebook_name = '08_recreate_figure_5'
figure_folder = os.path.join(common.FIGURE_FOLDER, notebook_name)
data_folder = os.path.join(common.DATA_FOLDER, notebook_name)
print('Figure folder:', figure_folder)
print('Data folder:', data_folder)

# Make the folders 
! mkdir -p $figure_folder
! mkdir -p $data_folder
# Out:
# Figure folder: figures/08_recreate_figure_5
# Data folder: data/08_recreate_figure_5

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
import macosko2015

urlname = macosko2015.BASE_URL + '/amacrine_expression.csv'
urlname
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-afd2daca1d32> in <module>()
#       1 import macosko2015
#       2
# ----> 3 urlname = macosko2015.BASE_URL + '/amacrine_expression.csv'
#       4 urlname
#
# AttributeError: module 'macosko2015' has no attribute 'BASE_URL'

# %%
expression = pd.read_csv()
expression.head()
# Out:
#                  1700025G04RIK  2610017I09RIK  2900011O08RIK  4833424O15RIK  \
# r1_GGGTGTCAGTGG              1              0             23              4
# r1_GTTTATATGCGC              5              0              9              3
# r1_TCTTCACTGGCT              5              0              6              0
# r1_TCATTTAGTCGA              2              1             14             16
# r1_GTCTATTCGGTT              0              0             11             19
#
#                  4930447C04RIK  6330403K07RIK  6430548M08RIK  8430419L09RIK  \
# r1_GGGTGTCAGTGG              3              7             10              4
# r1_GTTTATATGCGC              1              4              4              6
# r1_TCTTCACTGGCT              4              5              7              0
# r1_TCATTTAGTCGA              0              8              0              0
# r1_GTCTATTCGGTT              0              2             13              2
#
#                  A030009H04RIK  A830010M20RIK ...   YWHAG  YWHAH  ZCCHC12  \
# r1_GGGTGTCAGTGG              3              4 ...       7      4        0
# r1_GTTTATATGCGC              9              4 ...       3      5        1
# r1_TCTTCACTGGCT              3              9 ...       7      5        1
# r1_TCATTTAGTCGA              3              0 ...      11      4        1
# r1_GTCTATTCGGTT              1              1 ...       2     10        1
#
#                  ZCCHC18  ZEB2  ZFHX3  ZFP804A  ZMAT4  ZWINT  ZYX
# r1_GGGTGTCAGTGG        5     2      7        0      3      6    0
# r1_GTTTATATGCGC        8    11      4        2      3      8    0
# r1_TCTTCACTGGCT        4     3      0        3      3     11    2
# r1_TCATTTAGTCGA        5    13      0        0      0      6    0
# r1_GTCTATTCGGTT        2     1      0        1      2      1    0
#
# [5 rows x 614 columns]

# %%
csv = os.path.join(common.DATA_FOLDER, '03_clean_cluster_assignments', 
                             'cluster_names.csv')
cluster_names = pd.read_csv(csv, index_col=0, squeeze=True)
cluster_names.head()
# Out:
# cell
# r1_GGCCGCAGTCCG    cluster_02
# r1_CTTGTGCGGGAA    cluster_02
# r1_GCGCAACTGCTC    cluster_02
# r1_GATTGGGAGGCA    cluster_02
# r1_GTGCCGCCTCTC    cluster_25
# Name: cluster_id, dtype: object

# %%
expression, cells, genes = macosko2015.load_amacrine('pandas')

expression.head()
# Out:
#                  1700025G04RIK  2610017I09RIK  2900011O08RIK  4833424O15RIK  \
# r1_GGGTGTCAGTGG              1              0             23              4
# r1_GTTTATATGCGC              5              0              9              3
# r1_TCTTCACTGGCT              5              0              6              0
# r1_TCATTTAGTCGA              2              1             14             16
# r1_GTCTATTCGGTT              0              0             11             19
#
#                  4930447C04RIK  6330403K07RIK  6430548M08RIK  8430419L09RIK  \
# r1_GGGTGTCAGTGG              3              7             10              4
# r1_GTTTATATGCGC              1              4              4              6
# r1_TCTTCACTGGCT              4              5              7              0
# r1_TCATTTAGTCGA              0              8              0              0
# r1_GTCTATTCGGTT              0              2             13              2
#
#                  A030009H04RIK  A830010M20RIK ...   YWHAG  YWHAH  ZCCHC12  \
# r1_GGGTGTCAGTGG              3              4 ...       7      4        0
# r1_GTTTATATGCGC              9              4 ...       3      5        1
# r1_TCTTCACTGGCT              3              9 ...       7      5        1
# r1_TCATTTAGTCGA              3              0 ...      11      4        1
# r1_GTCTATTCGGTT              1              1 ...       2     10        1
#
#                  ZCCHC18  ZEB2  ZFHX3  ZFP804A  ZMAT4  ZWINT  ZYX
# r1_GGGTGTCAGTGG        5     2      7        0      3      6    0
# r1_GTTTATATGCGC        8    11      4        2      3      8    0
# r1_TCTTCACTGGCT        4     3      0        3      3     11    2
# r1_TCATTTAGTCGA        5    13      0        0      0      6    0
# r1_GTCTATTCGGTT        2     1      0        1      2      1    0
#
# [5 rows x 614 columns]

# %%
mean_cluster_expression = expression.groupby(cluster_names, axis=0).mean()
mean_cluster_expression.head()
# Out:
#             1700025G04RIK  2610017I09RIK  2900011O08RIK  4833424O15RIK  \
# cluster_id
# cluster_03       1.159091            0.0       1.022727       0.000000
# cluster_04       0.461538            0.0       0.923077       1.000000
# cluster_05       0.611111            0.0       3.722222       0.777778
# cluster_06       0.595238            0.0       5.023810       0.714286
# cluster_07       1.000000            0.0       4.981481       0.851852
#
#             4930447C04RIK  6330403K07RIK  6430548M08RIK  8430419L09RIK  \
# cluster_id
# cluster_03       0.477273       0.068182       1.568182       0.181818
# cluster_04       1.461538       0.538462       0.615385       0.153846
# cluster_05       0.722222       1.166667       1.722222       1.111111
# cluster_06       0.500000       1.380952       2.428571       0.547619
# cluster_07       0.296296       0.444444       3.018519       0.537037
#
#             A030009H04RIK  A830010M20RIK    ...        YWHAG     YWHAH  \
# cluster_id                                  ...
# cluster_03       0.704545       1.840909    ...     1.045455  1.886364
# cluster_04       0.769231       0.692308    ...     0.846154  1.692308
# cluster_05       2.333333       0.722222    ...     0.555556  0.944444
# cluster_06       2.333333       0.904762    ...     1.261905  1.238095
# cluster_07       2.000000       0.629630    ...     1.444444  1.277778
#
#              ZCCHC12   ZCCHC18      ZEB2     ZFHX3   ZFP804A     ZMAT4  \
# cluster_id
# cluster_03  0.000000  0.954545  0.568182  0.795455  0.000000  1.659091
# cluster_04  0.000000  1.538462  0.307692  1.153846  0.000000  0.615385
# cluster_05  0.222222  1.166667  3.166667  1.111111  0.111111  1.166667
# cluster_06  0.047619  1.023810  0.095238  1.285714  0.000000  0.452381
# cluster_07  0.037037  0.925926  0.185185  0.611111  0.111111  0.759259
#
#                ZWINT       ZYX
# cluster_id
# cluster_03  1.363636  0.250000
# cluster_04  1.000000  0.153846
# cluster_05  2.111111  0.111111
# cluster_06  1.404762  0.023810
# cluster_07  2.222222  0.055556
#
# [5 rows x 614 columns]

# %%
corr = mean_cluster_expression.T.corr()

# %%
sns.clustermap(corr)
# Out:
# /Users/olgabot/anaconda3/envs/macosko2015-env/lib/python3.6/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
expression_log = np.log2(expression+1)
print(expression_log.shape)
expression_log.head()
# Out:
# (714, 614)
#                  1700025G04RIK  2610017I09RIK  2900011O08RIK  4833424O15RIK  \
# r1_GGGTGTCAGTGG       1.000000            0.0       4.584963       2.321928
# r1_GTTTATATGCGC       2.584963            0.0       3.321928       2.000000
# r1_TCTTCACTGGCT       2.584963            0.0       2.807355       0.000000
# r1_TCATTTAGTCGA       1.584963            1.0       3.906891       4.087463
# r1_GTCTATTCGGTT       0.000000            0.0       3.584963       4.321928
#
#                  4930447C04RIK  6330403K07RIK  6430548M08RIK  8430419L09RIK  \
# r1_GGGTGTCAGTGG       2.000000       3.000000       3.459432       2.321928
# r1_GTTTATATGCGC       1.000000       2.321928       2.321928       2.807355
# r1_TCTTCACTGGCT       2.321928       2.584963       3.000000       0.000000
# r1_TCATTTAGTCGA       0.000000       3.169925       0.000000       0.000000
# r1_GTCTATTCGGTT       0.000000       1.584963       3.807355       1.584963
#
#                  A030009H04RIK  A830010M20RIK    ...        YWHAG     YWHAH  \
# r1_GGGTGTCAGTGG       2.000000       2.321928    ...     3.000000  2.321928
# r1_GTTTATATGCGC       3.321928       2.321928    ...     2.000000  2.584963
# r1_TCTTCACTGGCT       2.000000       3.321928    ...     3.000000  2.584963
# r1_TCATTTAGTCGA       2.000000       0.000000    ...     3.584963  2.321928
# r1_GTCTATTCGGTT       1.000000       1.000000    ...     1.584963  3.459432
#
#                  ZCCHC12   ZCCHC18      ZEB2     ZFHX3   ZFP804A     ZMAT4  \
# r1_GGGTGTCAGTGG      0.0  2.584963  1.584963  3.000000  0.000000  2.000000
# r1_GTTTATATGCGC      1.0  3.169925  3.584963  2.321928  1.584963  2.000000
# r1_TCTTCACTGGCT      1.0  2.321928  2.000000  0.000000  2.000000  2.000000
# r1_TCATTTAGTCGA      1.0  2.584963  3.807355  0.000000  0.000000  0.000000
# r1_GTCTATTCGGTT      1.0  1.584963  1.000000  0.000000  1.000000  1.584963
#
#                     ZWINT       ZYX
# r1_GGGTGTCAGTGG  2.807355  0.000000
# r1_GTTTATATGCGC  3.169925  0.000000
# r1_TCTTCACTGGCT  3.584963  1.584963
# r1_TCATTTAGTCGA  2.807355  0.000000
# r1_GTCTATTCGGTT  1.000000  0.000000
#
# [5 rows x 614 columns]

# %%
expression_log_mean = expression_log.groupby(cluster_names, axis=0).mean()
print(expression_log_mean.shape)
expression_log_mean.head()
# Out:
# (21, 614)
#             1700025G04RIK  2610017I09RIK  2900011O08RIK  4833424O15RIK  \
# cluster_id
# cluster_03       0.761215            0.0       0.651404       0.000000
# cluster_04       0.352689            0.0       0.750376       0.846154
# cluster_05       0.453885            0.0       1.881549       0.620551
# cluster_06       0.446545            0.0       2.244249       0.587185
# cluster_07       0.735147            0.0       2.048786       0.652297
#
#             4930447C04RIK  6330403K07RIK  6430548M08RIK  8430419L09RIK  \
# cluster_id
# cluster_03       0.372553       0.058749       1.012408       0.172386
# cluster_04       1.094525       0.538462       0.454376       0.153846
# cluster_05       0.582881       0.864926       1.086153       0.720960
# cluster_06       0.408808       0.961334       1.452744       0.426355
# cluster_07       0.280925       0.402868       1.601280       0.456700
#
#             A030009H04RIK  A830010M20RIK    ...        YWHAG     YWHAH  \
# cluster_id                                  ...
# cluster_03       0.600786       1.076626    ...     0.749521  1.068634
# cluster_04       0.673453       0.531299    ...     0.782302  1.075175
# cluster_05       1.395166       0.582881    ...     0.421387  0.718045
# cluster_06       1.423102       0.681609    ...     0.936275  0.897997
# cluster_07       1.277725       0.541938    ...     1.057767  0.920783
#
#              ZCCHC12   ZCCHC18      ZEB2     ZFHX3   ZFP804A     ZMAT4  \
# cluster_id
# cluster_03  0.000000  0.710153  0.433564  0.584822  0.000000  1.044052
# cluster_04  0.000000  1.044997  0.243840  0.852063  0.000000  0.506536
# cluster_05  0.222222  0.829156  1.566557  0.799930  0.088053  0.852214
# cluster_06  0.047619  0.763346  0.075474  0.929037  0.000000  0.398926
# cluster_07  0.037037  0.720528  0.118376  0.394430  0.092593  0.618827
#
#                ZWINT       ZYX
# cluster_id
# cluster_03  0.840946  0.240567
# cluster_04  0.564604  0.153846
# cluster_05  1.239841  0.088053
# cluster_06  0.990051  0.023810
# cluster_07  1.355065  0.055556
#
# [5 rows x 614 columns]

# %%
from scipy.cluster.hierarchy import dendrogram

# %%
import fastcluster
import polo

distances = fastcluster.pdist(expression_log_mean, metric='euclidean')

linkage = fastcluster.linkage(distances, method='ward')
linkage.shape
# Out:
# (20, 4)

# %%
dendrogram(linkage);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-8ab9d40234ea> in <module>()
# ----> 1 dendrogram(linkage);
#
# NameError: name 'dendrogram' is not defined

# %%
olo_linkage = polo.optimal_leaf_ordering(linkage, distances)
olo_linkage.shape
# Out:
# (20, 4)

# %%
from scipy.cluster import hierarchy

# %%
dendrogram(olo_linkage);

# %%
expression_log_mean.shape
# Out:
# (21, 614)

# %%
sns.clustermap(expression_log_mean, row_linkage=olo_linkage)
# Out:
# /Users/olgabot/anaconda3/envs/macosko2015-env/lib/python3.6/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
olo_linkage
# Out:
# array([[ 18.        ,  17.        ,   5.7423853 ,   2.        ],
#        [  8.        ,   9.        ,   6.00740907,   2.        ],
#        [ 21.        ,  19.        ,   7.2527819 ,   3.        ],
#        [  3.        ,   4.        ,   7.66982925,   2.        ],
#        [ 22.        ,  20.        ,   8.06800235,   3.        ],
#        [ 14.        ,  15.        ,   8.36646439,   2.        ],
#        [  5.        ,   7.        ,   9.34152688,   2.        ],
#        [ 16.        ,  26.        ,   9.84292001,   3.        ],
#        [  6.        ,  27.        ,  10.26315893,   3.        ],
#        [  1.        ,  25.        ,  11.18842383,   4.        ],
#        [ 28.        ,  23.        ,  11.27075963,   6.        ],
#        [ 29.        ,   2.        ,  11.40665472,   4.        ],
#        [ 12.        ,  13.        ,  12.86798028,   2.        ],
#        [ 31.        ,  33.        ,  13.56710103,   8.        ],
#        [ 30.        ,  34.        ,  14.91715178,  12.        ],
#        [ 32.        ,  24.        ,  15.90577869,   6.        ],
#        [  0.        ,  35.        ,  16.64277881,  13.        ],
#        [ 11.        ,  36.        ,  17.74672758,   7.        ],
#        [ 38.        ,  10.        ,  18.61661786,   8.        ],
#        [ 37.        ,  39.        ,  30.53904873,  21.        ]])

# %% [markdown]
# ## Figure 5a

# %%
def upperizer(genes):
    return [x.upper() for x in genes]

# %%
figure5a_genes = ['Nrxn2', 'Atp1b1', 'Pax6', 'Slc32a1', 'Slc6a1', 'Elavl3']
figure5a_genes_upper = upperizer(figure5a_genes)
figure5a_genes_upper
# Out:
# ['NRXN2', 'ATP1B1', 'PAX6', 'SLC32A1', 'SLC6A1', 'ELAVL3']

# %%
import xarray as xr

# %%
netcdf = os.path.join(common.DATA_FOLDER, '05_make_rentina_subsets_for_teaching', 
                      'differential_clusters.netcdf')
diff_clusters = xr.open_dataset(netcdf)
diff_clusters
# Out:
# <xarray.Dataset>
# Dimensions:        (cell_features: 1, cells: 6020, gene_features: 39, gene_symbol: 1339, genes: 1339)
# Coordinates:
#   * cells          (cells) |S15 b'r1_GGCCGCAGTCCG' b'r1_CTTGTGCGGGAA' ...
#     genes          (gene_symbol) |S13 b'1500015O10RIK' b'1500016L03RIK' ...
# Dimensions without coordinates: cell_features, gene_features, gene_symbol
# Data variables:
#     expression     (cells, genes) int32 0 0 5 4 7 28 5 0 33 0 1 5 19 7 0 26 ...
#     cell_metadata  (cells, cell_features) |S10 b'cluster_02' b'cluster_02' ...
#     gene_metadata  (genes, gene_features) bool False False False False False ...

# %%
# # figure5a_expression = diff_clusters.expression.loc[:, figure5a_genes_upper]
# figure5a_expression = diff_clusters.expression.sel_points(genes=figure5a_genes_upper)
# print(figure5a_expression.shape)
# figure5a_expression.head()

# %%
# %pdb
# Out:
# Automatic pdb calling has been turned OFF

# %%
diff_clusters.loc[dict(cells=b'r1_CTTGTGCGGGAA')]
# Out:
# <xarray.Dataset>
# Dimensions:        (cell_features: 1, gene_features: 39, gene_symbol: 1339, genes: 1339)
# Coordinates:
#     cells          |S15 b'r1_CTTGTGCGGGAA'
#     genes          (gene_symbol) |S13 b'1500015O10RIK' b'1500016L03RIK' ...
# Dimensions without coordinates: cell_features, gene_features, gene_symbol
# Data variables:
#     expression     (genes) int32 0 0 9 4 4 33 4 0 43 0 0 1 16 12 0 15 0 0 4 ...
#     cell_metadata  (cell_features) |S10 b'cluster_02'
#     gene_metadata  (genes, gene_features) bool False False False False False ...

# %%
diff_clusters.sel(gene_symbol=dict(genes='PAX6'))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-89-418a679d7a4d> in <module>()
# ----> 1 diff_clusters.sel(gene_symbol=dict(genes='PAX6'))
#
# ~/anaconda3/envs/macosko2015-env/lib/python3.6/site-packages/xarray/core/dataset.py in sel(self, method, tolerance, drop, **indexers)
#    1206             self, indexers, method=method, tolerance=tolerance
#    1207         )
# -> 1208         result = self.isel(drop=drop, **pos_indexers)
#    1209         return result._replace_indexes(new_indexes)
#    1210
#
# ~/anaconda3/envs/macosko2015-env/lib/python3.6/site-packages/xarray/core/dataset.py in isel(self, drop, **indexers)
#    1141         for name, var in iteritems(self._variables):
#    1142             var_indexers = dict((k, v) for k, v in indexers if k in var.dims)
# -> 1143             new_var = var.isel(**var_indexers)
#    1144             if not (drop and name in var_indexers):
#    1145                 variables[name] = new_var
#
# ~/anaconda3/envs/macosko2015-env/lib/python3.6/site-packages/xarray/core/variable.py in isel(self, **indexers)
#     568             if dim in indexers:
#     569                 key[i] = indexers[dim]
# --> 570         return self[tuple(key)]
#     571
#     572     def squeeze(self, dim=None):
#
# ~/anaconda3/envs/macosko2015-env/lib/python3.6/site-packages/xarray/core/variable.py in __getitem__(self, key)
#     398         dims = tuple(dim for k, dim in zip(key, self.dims)
#     399                      if not isinstance(k, integer_types))
# --> 400         values = self._indexable_data[key]
#     401         # orthogonal indexing should ensure the dimensionality is consistent
#     402         if hasattr(values, 'ndim'):
#
# ~/anaconda3/envs/macosko2015-env/lib/python3.6/site-packages/xarray/core/indexing.py in __getitem__(self, key)
#     429
#     430     def __getitem__(self, key):
# --> 431         return type(self)(_wrap_numpy_scalars(self.array[key]))
#     432
#     433     def __setitem__(self, key, value):
#
# IndexError: arrays used as indices must be of integer (or boolean) type

# %%
figure5a_expression_mean = \
    figure5a_expression.groupby(cluster_names, axis=0).mean()
print(figure5a_expression_mean.shape)
figure5a_expression_mean.head()
# Out:
# (21, 6)
#                NRXN2     ATP1B1      PAX6   SLC32A1    SLC6A1    ELAVL3
# cluster_id
# cluster_03  1.409091  10.772727  1.454545  1.568182  2.090909  1.477273
# cluster_04  1.846154   2.230769  5.692308  0.615385  1.000000  0.846154
# cluster_05  3.222222  10.111111  4.888889  1.944444  3.944444  1.888889
# cluster_06  5.666667   8.619048  6.404762  2.119048  4.238095  2.214286
# cluster_07  4.814815   8.740741  6.296296  1.981481  3.759259  2.703704

# %%
figure5a_expression_tidy = figure5a_expression_mean.unstack().reset_index()
figure5a_expression_tidy = figure5a_expression_tidy.rename(
    columns={'level_0': 'gene_symbol', 'level_1': 'barcode', 0: 'expression'})
figure5a_expression_tidy['log_expression'] = np.log2(figure5a_expression_tidy['expression'] + 1)
print(figure5a_expression_tidy.shape)
# figure5a_expression_tidy = figure5a_expression_tidy.join(cluster_names, on='barcode')
figure5a_expression_tidy.head()
# Out:
# (126, 4)
#   gene_symbol  cluster_id  expression  log_expression
# 0       NRXN2  cluster_03    1.409091        1.268489
# 1       NRXN2  cluster_04    1.846154        1.509014
# 2       NRXN2  cluster_05    3.222222        2.078003
# 3       NRXN2  cluster_06    5.666667        2.736966
# 4       NRXN2  cluster_07    4.814815        2.539733

# %%
import altair

altair.Chart(figure5a_expression_tidy).mark_circle().encode(
    size='expression', x=altair.X('gene_symbol'), y=altair.Y('cluster_id'))
# Out:
# <div class="vega-embed" id="99a079dc-97ba-463d-a1cb-6350503591ab"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
import altair

altair.Chart(figure5a_expression_tidy).mark_circle().encode(
    size='log_expression', x=altair.X('gene_symbol'), y=altair.Y('cluster_id'))
# Out:
# <div class="vega-embed" id="dbde94ff-df5a-4c1b-93b5-67bcefe4c2a6"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
figure5a_expression_median = figure5a_expression.groupby(cluster_names, axis=1).median()

# %%
figure5a_expression_mean = figure5a_expression_tidy.groupby('cluster_id').mean()
figure5a_expression_mean.head()
# Out:
#             expression  log_expression
# cluster_id
# cluster_03    3.128788        1.312279
# cluster_04    2.038462        1.200985
# cluster_05    4.333333        1.829966
# cluster_06    4.876984        2.121230
# cluster_07    4.716049        2.057740

# %% [markdown]
# Try the same thing, but with:
#
# - Mean within clusters, log expression
# - **Median** within clusters, raw counts
# - **Median** within clusters, log expression

# %%
altair.Chart(figure5a_expression_tidy).mark_circle().encode(
    size='log_expression', x=altair.X('gene_symbol'), y=altair.Y('cluster_id'))
# Out:
# <div class="vega-embed" id="c90e8e79-133a-4ec3-b368-2f313f102711"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Figure 5b

# %%
figure5b_genes = ['Chat', "Gad1", 'Gad2', 'Slc17a8', 'Slc6a9', 'Gjd2', 'Gjd2', 'Ebf3']
figure5b_genes_upper = upperizer(figure5b_genes)
figure5b_genes_upper
# Out:
# ['CHAT', 'GAD1', 'GAD2', 'SLC17A8', 'SLC6A9', 'GJD2', 'GJD2', 'EBF3']

# %%
figure5b_expression = expression[figure5b_genes_upper]
figure5b_expression.head()
# Out:
#                  CHAT  GAD1  GAD2  SLC17A8  SLC6A9  GJD2  GJD2  EBF3
# r1_GGGTGTCAGTGG     0     8    16        0       0     2     2     0
# r1_GTTTATATGCGC     0    10     6        0       1     0     0     0
# r1_TCTTCACTGGCT     0    14     6        0       0     0     0     0
# r1_TCATTTAGTCGA     0     6     1        0       0     1     1     0
# r1_GTCTATTCGGTT     0     7    16        0       0     0     0     0

# %%
figure5b_tidy = pd.melt(figure5b_expression.reset_index(), id_vars='index', 
               value_name='expression', var_name='gene_symbol')
figure5b_tidy = figure5b_tidy.rename(columns={'index': 'barcode'})
print(figure5b_tidy.shape)
figure5b_tidy.head()
# Out:
# (5712, 3)
#            barcode gene_symbol  expression
# 0  r1_GGGTGTCAGTGG        CHAT           0
# 1  r1_GTTTATATGCGC        CHAT           0
# 2  r1_TCTTCACTGGCT        CHAT           0
# 3  r1_TCATTTAGTCGA        CHAT           0
# 4  r1_GTCTATTCGGTT        CHAT           0

# %%
tidy_clusters = tidy.join(cluster_names, on='barcode')
print(tidy_clusters.shape)
tidy_clusters.head()
# Out:
# (5712, 4)
#            barcode gene_symbol  expression  cluster_id
# 0  r1_GGGTGTCAGTGG        CHAT           0  cluster_06
# 1  r1_GTTTATATGCGC        CHAT           0  cluster_05
# 2  r1_TCTTCACTGGCT        CHAT           0  cluster_13
# 3  r1_TCATTTAGTCGA        CHAT           0  cluster_08
# 4  r1_GTCTATTCGGTT        CHAT           0  cluster_10

# %%
# for gene, df in tidy_clusters.groupby('gene_symbol'):
#     fig, ax = plt.subplots()
#     sns.violinplot(x)

# %%
sns.set(context='paper', style='whitegrid')

# %%
sns.violinplot??

# %%
clusters = tidy_clusters['cluster_id'].unique()
clusters.sort()
clusters
# Out:
# array(['cluster_03', 'cluster_04', 'cluster_05', 'cluster_06',
#        'cluster_07', 'cluster_08', 'cluster_09', 'cluster_10',
#        'cluster_11', 'cluster_12', 'cluster_13', 'cluster_14',
#        'cluster_15', 'cluster_16', 'cluster_17', 'cluster_18',
#        'cluster_19', 'cluster_20', 'cluster_21', 'cluster_22', 'cluster_23'], dtype=object)

# %%
g = sns.FacetGrid(tidy_clusters, col='gene_symbol', size=4, aspect=0.25,
                  gridspec_kws=dict(hspace=0, wspace=0), sharex=False)
g.map(sns.violinplot, 'expression', 'cluster_id', orient='h', scale='width', 
      linewidth=1, order=clusters, palette='husl', inner=None, cut=True)
g.set(xlabel='')
g.set_titles('{col_name}')

# %% [markdown]
# ## Don't see bimodality .. try log2

# %%
tidy_clusters['log_expression'] = np.log2(tidy_clusters['expression'] + 1)

# %%
g = sns.FacetGrid(tidy_clusters, col='gene_symbol', size=4, aspect=0.25,
                  gridspec_kws=dict(hspace=0, wspace=0), sharex=False)
g.map(sns.violinplot, 'log_expression', 'cluster_id', orient='h', 
      scale='width', linewidth=1, order=clusters, palette='husl', 
      inner=None, cut=True)
g.set(xlabel='', xticks=[])
g.set_titles('{col_name}')
for ax in g.axes.flat:
    xmin, xmax = ax.get_xlim()
    ax.set(xlim=(0, xmax))
    
g.savefig(os.path.join(figure_folder, 'figure5b.pdf'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-e9891136d309> in <module>()
# ----> 1 g = sns.FacetGrid(tidy_clusters, col='gene_symbol', size=4, aspect=0.25,
#       2                   gridspec_kws=dict(hspace=0, wspace=0), sharex=False)
#       3 g.map(sns.violinplot, 'log_expression', 'cluster_id', orient='h',
#       4       scale='width', linewidth=1, order=clusters, palette='husl',
#       5       inner=None, cut=True)
#
# NameError: name 'tidy_clusters' is not defined

# %% [markdown]
# ## Figure 5c - as an exercise

# %%
figure5c_genes = ['Gng7', 'Gbx2', 'Tpbg', 'Slitrk6', 'Maf', 'Tac2', 'Loxl2', 'Vip', 'Glra1',
                  'Igfbp5', 'Pdgfra', 'Slc35d3', 'Car3', 'Fgf1', 'Igf1', 'Col12a1', 'Ptgds',
                  'Ppp1r17', 'Cck', 'Shisa9', 'Pou3f3']
figure5c_genes_upper = figure5c_genes
figure53_expression = expression[figure5c_genes_upper]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-36ce3bb1bb25> in <module>()
#       3                   'Ppp1r17', 'Cck', 'Shisa9', 'Pou3f3']
#       4 figure5c_genes_upper = figure5c_genes
# ----> 5 figure53_expression = expression[figure5c_genes_upper]
#
# ~/anaconda3/envs/macosko2015-env/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# ~/anaconda3/envs/macosko2015-env/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2003             return self.take(indexer, axis=1, convert=True)
#    2004
#
# ~/anaconda3/envs/macosko2015-env/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1229                 mask = check == -1
#    1230                 if mask.any():
# -> 1231                     raise KeyError('%s not in index' % objarr[mask])
#    1232
#    1233                 return _values_from_object(indexer)
#
# KeyError: "['Gng7' 'Gbx2' 'Tpbg' 'Slitrk6' 'Maf' 'Tac2' 'Loxl2' 'Vip' 'Glra1' 'Igfbp5'\n 'Pdgfra' 'Slc35d3' 'Car3' 'Fgf1' 'Igf1' 'Col12a1' 'Ptgds' 'Ppp1r17' 'Cck'\n 'Shisa9' 'Pou3f3'] not in index"

# %%
g = sns.FacetGrid(tidy_clusters, col='gene_symbol', size=4, aspect=0.25,
                  gridspec_kws=dict(hspace=0, wspace=0), sharex=False)
g.map(sns.violinplot, 'log_expression', 'cluster_id', orient='h', scale='width', 
      linewidth=1, order=clusters, palette='husl', inner=None, cut=True)
g.set(xlabel='', xticks=[])
g.set_titles('{col_name}')
for ax in g.axes.flat:
    xmin, xmax = ax.get_xlim()
    ax.set(xlim=(0, xmax))

# %% [markdown]
# ### Robust PCA on Figure 5c

# %%
import sys
sys.path.append('/Users/olgabot/code/robust-pca/')

import r_pca

# %%
amacrine_rpca.fit??

# %%
amacrine_rpca = r_pca.R_pca(expression.as_matrix())
lowrank, sparse = amacrine_rpca.fit()
# Out:
# iteration: 1, error: 89719.33798885415
# iteration: 100, error: 0.6330691800608881
# iteration: 137, error: 0.2786376210941671

# %%
def tidify(data2d):
    data_tidy = pd.melt(data2d.reset_index(), id_vars='index', 
               value_name='expression', var_name='gene_symbol')
    data_tidy = data_tidy.rename(columns={'index': 'barcode'})
    return data_tidy

# %%
lowrank_df = pd.DataFrame(lowrank, index=expression.index, columns=expression.columns)
print(lowrank_df.shape)
lowrank_df.head()
# Out:
# (714, 614)
#                  1700025G04RIK  2610017I09RIK  2900011O08RIK  4833424O15RIK  \
# r1_GGGTGTCAGTGG       1.472442       0.002982      11.767506       2.432508
# r1_GTTTATATGCGC       1.495240      -0.000160       9.000085       2.703310
# r1_TCTTCACTGGCT       1.437269      -0.001336       6.315864       1.318977
# r1_TCATTTAGTCGA       1.126102      -0.006785       7.032396       2.193180
# r1_GTCTATTCGGTT       0.989302       0.005142       7.100116       2.701279
#
#                  4930447C04RIK  6330403K07RIK  6430548M08RIK  8430419L09RIK  \
# r1_GGGTGTCAGTGG       0.990557       3.185586       8.062434       1.013607
# r1_GTTTATATGCGC       1.916876       3.345178       5.861134       0.949970
# r1_TCTTCACTGGCT       3.269060       2.105499       6.664976       0.107632
# r1_TCATTTAGTCGA       2.139370       3.064916       4.405724       0.488815
# r1_GTCTATTCGGTT       0.733686       2.593193       6.398625       0.418440
#
#                  A030009H04RIK  A830010M20RIK    ...        YWHAG     YWHAH  \
# r1_GGGTGTCAGTGG       5.784146       2.163623    ...     4.844230  4.104141
# r1_GTTTATATGCGC       5.982487       2.134148    ...     3.484867  4.722510
# r1_TCTTCACTGGCT       4.491492       1.449185    ...     5.587380  4.999817
# r1_TCATTTAGTCGA       3.968338       0.903634    ...     4.546031  4.312819
# r1_GTCTATTCGGTT       4.098714       1.004176    ...     3.302288  4.136620
#
#                   ZCCHC12   ZCCHC18      ZEB2     ZFHX3   ZFP804A     ZMAT4  \
# r1_GGGTGTCAGTGG  0.007318  3.449245  1.587405  1.261298  0.034406  1.807231
# r1_GTTTATATGCGC  0.007416  4.371290  3.276108  1.005352  0.794364  1.852125
# r1_TCTTCACTGGCT  0.002860  4.000011  3.000065  0.086543  0.943367  0.871208
# r1_TCATTTAGTCGA  0.010187  4.061080  2.929740  0.079967  0.486353  0.961568
# r1_GTCTATTCGGTT  0.005958  2.857335  1.584070  0.586255  0.392932  0.932113
#
#                     ZWINT       ZYX
# r1_GGGTGTCAGTGG  6.000043  0.025569
# r1_GTTTATATGCGC  6.017725 -0.002815
# r1_TCTTCACTGGCT  6.944142  0.118463
# r1_TCATTTAGTCGA  5.880449 -0.012339
# r1_GTCTATTCGGTT  3.993389 -0.000792
#
# [5 rows x 614 columns]

# %%
lowrank_5c = lowrank_df[]
